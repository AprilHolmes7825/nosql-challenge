# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
#query =
query = {'scores.Hygiene': {'$gt': 20}}
results = db.establishments.find(query)

# Use count_documents to display the number of documents in the result
print(establishments.count_documents(query))

# Display the first document in the results using pprint
pprint(results[0])
# Out:
# 7
# {'AddressLine1': 'Skyline Hotel',
#  'AddressLine2': 'Chelmsford Road',
#  'AddressLine3': 'Barnston',
#  'AddressLine4': 'Dunmow',
#  'BusinessName': 'Inferno',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4650.02974294374,
#  'FHRSID': 1349147,
#  'LocalAuthorityBusinessID': '21/00036/COM',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM6 1LP',
#  'RatingDate': '2022-01-27T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65bbbec6600dff4571813918'),
#  'establishments': {'RatingValue': None,
#                     'ge0code': {'latitude': None},
#                     'geocode': {'longitude': None},
#                     'latitude': None,
#                     'longitude': None},
#  'geocode': {'latitude': Decimal128('51.85643'),
#              'longitude': Decimal128('0.383023')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1349147',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 25, 'Structural': 20}}

# %%
import pandas as pd
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(df))
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# Rows in DataFrame:  7
#                         _id   FHRSID  ChangesByServerID  \
# 0  65bbbec6600dff4571813918  1349147                  0
# 1  65bbbec6600dff4571814351   785554                  0
# 2  65bbbec6600dff4571814507   514156                  0
# 3  65bbbec6600dff4571814516   514651                  0
# 4  65bbbec6600dff4571814552   514221                  0
# 5  65bbbec6600dff4571814596   552296                  0
# 6  65bbbec6600dff4571814710  1351355                  0
#
#   LocalAuthorityBusinessID                                   BusinessName  \
# 0             21/00036/COM                                        Inferno
# 1            08/00054/FOOD                       Stratford News And Wines
# 2                      147                            The Plough & Harrow
# 3                    47178                                         Chicks
# 4                    17220  The Continental Food Exchange/TFC Leytonstone
# 5                    63877                                            O42
# 6                   348976                       Busy Bees at Leytonstone
#
#               BusinessType  BusinessTypeID                      AddressLine1  \
# 0   Takeaway/sandwich shop            7844                     Skyline Hotel
# 1        Retailers - other            4613                  107 Romford Road
# 2        Pub/bar/nightclub            7843
# 3   Takeaway/sandwich shop            7844
# 4        Retailers - other            4613
# 5  Restaurant/Cafe/Canteen               1
# 6          Caring Premises               5  Whipps Cross University Hospital
#
#                     AddressLine2 AddressLine3  ...  \
# 0                Chelmsford Road     Barnston  ...
# 1                      Stratford       London  ...
# 2      419 High Road Leytonstone               ...
# 3                  497 High Road               ...
# 4  647-661 High Road Leytonstone               ...
# 5      885 High Road Leytonstone               ...
# 6              Whipps Cross Road               ...
#
#                  LocalAuthorityEmailAddress  \
# 0     environmentalhealth@uttlesford.gov.uk
# 1                        food@newham.gov.uk
# 2  environmentalhealth@walthamforest.gov.uk
# 3  environmentalhealth@walthamforest.gov.uk
# 4  environmentalhealth@walthamforest.gov.uk
# 5  environmentalhealth@walthamforest.gov.uk
# 6  environmentalhealth@walthamforest.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 25, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 25, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...       FHRS
#
#                                             geocode RightToReply     Distance  \
# 0     {'longitude': 0.383023, 'latitude': 51.85643}               4650.029743
# 1    {'longitude': 0.008382, 'latitude': 51.542772}               4652.047527
# 2    {'longitude': 0.006434, 'latitude': 51.558138}               4652.681025
# 3  {'longitude': 0.0071334, 'latitude': 51.5593505}               4652.699935
# 4    {'longitude': 0.009602, 'latitude': 51.563902}               4652.776654
# 5    {'longitude': 0.014137, 'latitude': 51.570848}               4652.865838
# 6  {'longitude': 0.0034702, 'latitude': 51.5774342}               4653.495442
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 1            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 2            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 3            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 4            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 5            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 6             True  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links  \
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
#                                       establishments
# 0  {'longitude': None, 'latitude': None, 'RatingV...
# 1  {'longitude': None, 'latitude': None, 'RatingV...
# 2  {'longitude': None, 'latitude': None, 'RatingV...
# 3  {'longitude': None, 'latitude': None, 'RatingV...
# 4  {'longitude': None, 'latitude': None, 'RatingV...
# 5  {'longitude': None, 'latitude': None, 'RatingV...
# 6  {'longitude': None, 'latitude': None, 'RatingV...
#
# [7 rows x 29 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
#query = {'LocalAuthorityName': 'London', 'RatingValue': {'$gte': 4}}
query = {'LocalAuthorityName': {'$regex': "London"}, 'RatingValue': {'$gte': 4}}
results = db.establishments.find(query)

# Use count_documents to display the number of documents in the result
print(establishments.count_documents(query))

# Display the first document in the results using pprint
pprint(results[0])
# Out:
# 33
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65bbbec4600dff457180ecb6'),
#  'establishments': {'RatingValue': None,
#                     'ge0code': {'latitude': None},
#                     'geocode': {'longitude': None},
#                     'latitude': None,
#                     'longitude': None},
#  'geocode': {'latitude': Decimal128('51.369321'),
#              'longitude': Decimal128('0.508551')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(df))
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# Rows in DataFrame:  37
#                         _id   FHRSID  ChangesByServerID  \
# 0  65bbbec4600dff457180ecb6   621707                  0
# 1  65bbbec5600dff457180efdb  1130836                  0
# 2  65bbbec5600dff457180fb2a   293783                  0
# 3  65bbbec5600dff4571810137  1523645                  0
# 4  65bbbec5600dff4571810927   294474                  0
# 5  65bbbec5600dff457181092a  1315095                  0
# 6  65bbbec5600dff4571811031   294900                  0
# 7  65bbbec6600dff457181313c  1252616                  0
# 8  65bbbec6600dff4571813141   293756                  0
# 9  65bbbec6600dff4571813508   902473                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000038853                       Gourmet Kitchen
# 4             PI/000014647              Tilbury Seafarers Centre
# 5             PI/000036464  Coombs Catering t/a The Lock and Key
# 6             PI/000019066                            Mv Valulla
# 7             PI/000035653                             Froottree
# 8             PI/000002538                         Tereza Joanne
# 9             PI/000029852                         Pret A Manger
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3   Takeaway/sandwich shop            7844
# 4  Restaurant/Cafe/Canteen               1
# 5  Restaurant/Cafe/Canteen               1
# 6  Other catering premises            7841
# 7  Other catering premises            7841
# 8  Other catering premises            7841
# 9   Takeaway/sandwich shop            7844
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                                   1 London Gateway
# 4                          Tenants Row Tilbury Docks
# 5                                  Leslie Ford House
# 6  Reeds River Cruises LtdKings ReachRiver Thames...
# 7                   Tereza Joanne King George V Lock
# 8  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 9                               Retail Unit 2 Gate 3
#
#                             AddressLine2 AddressLine3  ...  \
# 0                            Sheppy Kent               ...
# 1       Cherry Garden Street Rotherhithe     Charlton  ...
# 2                   South Benfleet Essex               ...
# 3  London Gateway Drive Stanford-Le-Hope               ...
# 4                          Tilbury Essex               ...
# 5                                Tilbury     Charlton  ...
# 6                                 London               ...
# 7              Woolwich Manor Way London     Charlton  ...
# 8                                 London               ...
# 9          West Pier London City Airport               ...
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1  publicprotection@cityoflondon.gov.uk
# 2  publicprotection@cityoflondon.gov.uk
# 3  publicprotection@cityoflondon.gov.uk
# 4  publicprotection@cityoflondon.gov.uk
# 5  publicprotection@cityoflondon.gov.uk
# 6  publicprotection@cityoflondon.gov.uk
# 7  publicprotection@cityoflondon.gov.uk
# 8  publicprotection@cityoflondon.gov.uk
# 9  publicprotection@cityoflondon.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 8  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 5, 'Structural': 15, 'ConfidenceIn...       FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.508551, 'latitude': 51.369321}
# 1  {'longitude': 0.249255999922752, 'latitude': 5...
# 2     {'longitude': 0.561954, 'latitude': 51.543831}
# 3   {'longitude': 0.4596371, 'latitude': 51.5100659}
# 4     {'longitude': 0.346325, 'latitude': 51.464078}
# 5  {'longitude': 0.346336990594864, 'latitude': 5...
# 6     {'longitude': 0.287555, 'latitude': 51.504071}
# 7  {'longitude': 0.0693250000476837, 'latitude': ...
# 8     {'longitude': 0.069286, 'latitude': 51.501121}
# 9     {'longitude': 0.048006, 'latitude': 51.503733}
#
#       Distance NewRatingPending  \
# 0  4627.439468            False
# 1  4627.873179            False
# 2  4631.968418            False
# 3  4634.428121            False
# 4  4636.847650            False
# 5  4636.846754            False
# 6  4640.460834            False
# 7  4648.300000            False
# 8  4648.301822            False
# 9  4649.173485            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links  \
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
#                                       establishments
# 0  {'longitude': None, 'latitude': None, 'RatingV...
# 1  {'longitude': None, 'latitude': None, 'RatingV...
# 2  {'longitude': None, 'latitude': None, 'RatingV...
# 3  {'longitude': None, 'latitude': None, 'RatingV...
# 4  {'longitude': None, 'latitude': None, 'RatingV...
# 5  {'longitude': None, 'latitude': None, 'RatingV...
# 6  {'longitude': None, 'latitude': None, 'RatingV...
# 7  {'longitude': None, 'latitude': None, 'RatingV...
# 8  {'longitude': None, 'latitude': None, 'RatingV...
# 9  {'longitude': None, 'latitude': None, 'RatingV...
#
# [10 rows x 29 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
query = {'BusinessName': 'Penang Flavours'}
results = db.establishments.find(query, {"_id" : 0, 'geocode.latitude': 1, "geocode.longitude" : 1})
for i in range(1):
    pprint(results[i])
# Out:
# {'geocode': {'latitude': Decimal128('51.49014200'),
#              'longitude': Decimal128('0.08384000')}}

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01


latitude = 51.49014200
longitude = 0.08384000

query = {'$match': 
        {'RatingValue': 5,
         'geocode.latitude': {'$lte': latitude + .01},
         'geocode.latitude': {'$gte': latitude -.01},
         'geocode.longitude': {'$lte': longitude + .01},
         'geocode.longitude': {'$gte': longitude - .01}}
         }

sort =  {'$sort': { 'scores.Hygiene': 1 }}

pipeline = [query, sort]

# Print the results
results = list(establishments.aggregate(pipeline))
pprint(results[0:5])
# Out:
# [{'AddressLine1': '15 - 21 Old Pier Street',
#   'AddressLine2': 'Walton On The Naze',
#   'AddressLine3': 'Essex',
#   'AddressLine4': '',
#   'BusinessName': 'Yates Fish Bar',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4617.9096191396775,
#   'FHRSID': 611936,
#   'LocalAuthorityBusinessID': '1545/FOOD',
#   'LocalAuthorityCode': '120',
#   'LocalAuthorityEmailAddress': 'fhsadmin@tendringdc.gov.uk',
#   'LocalAuthorityName': 'Tendring',
#   'LocalAuthorityWebSite': 'http://www.tendringdc.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'CO14 8AH',
#   'RatingDate': '2020-02-24T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65bbbec4600dff457180d5f8'),
#   'establishments': {'RatingValue': None,
#                      'ge0code': {'latitude': None},
#                      'geocode': {'longitude': None},
#                      'latitude': None,
#                      'longitude': None},
#   'geocode': {'latitude': Decimal128('51.848696'),
#               'longitude': Decimal128('1.270904')},
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/611936',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': None,
#              'Hygiene': None,
#              'Structural': None}},
#  {'AddressLine1': 'Walton and Frinton Yacht Club',
#   'AddressLine2': 'Mill Lane',
#   'AddressLine3': 'Walton On The Naze',
#   'AddressLine4': 'Essex',
#   'BusinessName': 'Walton And Frinton Yacht Club',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4618.100788039521,
#   'FHRSID': 612149,
#   'LocalAuthorityBusinessID': '2718/FOOD',
#   'LocalAuthorityCode': '120',
#   'LocalAuthorityEmailAddress': 'fhsadmin@tendringdc.gov.uk',
#   'LocalAuthorityName': 'Tendring',
#   'LocalAuthorityWebSite': 'http://www.tendringdc.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'CO14 8PF',
#   'RatingDate': '2017-01-24T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65bbbec4600dff457180d679'),
#   'establishments': {'RatingValue': None,
#                      'ge0code': {'latitude': None},
#                      'geocode': {'longitude': None},
#                      'latitude': None,
#                      'longitude': None},
#   'geocode': {'latitude': Decimal128('51.851497'),
#               'longitude': Decimal128('1.268522')},
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/612149',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': None,
#              'Hygiene': None,
#              'Structural': None}},
#  {'AddressLine1': '80 Hamilton Road',
#   'AddressLine2': 'Felixstowe',
#   'AddressLine3': 'Suffolk',
#   'AddressLine4': '',
#   'BusinessName': 'Subway',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'ChangesByServerID': 0,
#   'Distance': 4619.377041875151,
#   'FHRSID': 1213083,
#   'LocalAuthorityBusinessID': '19/00489/CP',
#   'LocalAuthorityCode': '302',
#   'LocalAuthorityEmailAddress': 'environment@eastsuffolk.gov.uk',
#   'LocalAuthorityName': 'East Suffolk',
#   'LocalAuthorityWebSite': 'http://www.eastsuffolk.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'IP11 7AF',
#   'RatingDate': '2022-03-11T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65bbbec4600dff457180d875'),
#   'establishments': {'RatingValue': None,
#                      'ge0code': {'latitude': None},
#                      'geocode': {'longitude': None},
#                      'latitude': None,
#                      'longitude': None},
#   'geocode': {'latitude': Decimal128('51.963229'),
#               'longitude': Decimal128('1.35178')},
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1213083',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': None,
#              'Hygiene': None,
#              'Structural': None}},
#  {'AddressLine1': 'Three Mariners Inn',
#   'AddressLine2': '193 High Road',
#   'AddressLine3': 'Trimley St Mary',
#   'AddressLine4': 'Suffolk',
#   'BusinessName': 'The Mariners',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4621.544847483959,
#   'FHRSID': 667642,
#   'LocalAuthorityBusinessID': '13/50646/CP',
#   'LocalAuthorityCode': '302',
#   'LocalAuthorityEmailAddress': 'environment@eastsuffolk.gov.uk',
#   'LocalAuthorityName': 'East Suffolk',
#   'LocalAuthorityWebSite': 'http://www.eastsuffolk.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'IP11 0TN',
#   'RatingDate': '2022-03-11T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65bbbec4600dff457180dd67'),
#   'establishments': {'RatingValue': None,
#                      'ge0code': {'latitude': None},
#                      'geocode': {'longitude': None},
#                      'latitude': None,
#                      'longitude': None},
#   'geocode': {'latitude': Decimal128('51.984696'),
#               'longitude': Decimal128('1.313746')},
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/667642',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': None,
#              'Hygiene': None,
#              'Structural': None}},
#  {'AddressLine1': 'Hamford View',
#   'AddressLine2': 'Clacton Road',
#   'AddressLine3': 'Little Oakley',
#   'AddressLine4': 'Essex',
#   'BusinessName': 'Hamford View',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4622.042474821603,
#   'FHRSID': 958510,
#   'LocalAuthorityBusinessID': '17/00038/FOOD',
#   'LocalAuthorityCode': '120',
#   'LocalAuthorityEmailAddress': 'fhsadmin@tendringdc.gov.uk',
#   'LocalAuthorityName': 'Tendring',
#   'LocalAuthorityWebSite': 'http://www.tendringdc.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'CO12 5JJ',
#   'RatingDate': '2019-06-17T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65bbbec4600dff457180de11'),
#   'establishments': {'RatingValue': None,
#                      'ge0code': {'latitude': None},
#                      'geocode': {'longitude': None},
#                      'latitude': None,
#                      'longitude': None},
#   'geocode': {'latitude': Decimal128('51.912376'),
#               'longitude': Decimal128('1.222682')},
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/958510',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': None,
#              'Hygiene': None,
#              'Structural': None}}]

# %%
# Convert result to Pandas DataFrame
top_5 = results[0:5]
#print(len(top_5))

result_df = pd.DataFrame(top_5)
print("Rows in DataFrame: ", len(result_df))
result_df.head(10)
# Out:
# Rows in DataFrame:  5
#                         _id   FHRSID  ChangesByServerID  \
# 0  65bbbec4600dff457180d5f8   611936                  0
# 1  65bbbec4600dff457180d679   612149                  0
# 2  65bbbec4600dff457180d875  1213083                  0
# 3  65bbbec4600dff457180dd67   667642                  0
# 4  65bbbec4600dff457180de11   958510                  0
#
#   LocalAuthorityBusinessID                   BusinessName  \
# 0                1545/FOOD                 Yates Fish Bar
# 1                2718/FOOD  Walton And Frinton Yacht Club
# 2              19/00489/CP                         Subway
# 3              13/50646/CP                   The Mariners
# 4            17/00038/FOOD                   Hamford View
#
#               BusinessType  BusinessTypeID                   AddressLine1  \
# 0  Restaurant/Cafe/Canteen               1        15 - 21 Old Pier Street
# 1  Restaurant/Cafe/Canteen               1  Walton and Frinton Yacht Club
# 2  Other catering premises            7841               80 Hamilton Road
# 3        Pub/bar/nightclub            7843             Three Mariners Inn
# 4  Restaurant/Cafe/Canteen               1                   Hamford View
#
#          AddressLine2        AddressLine3  ...  \
# 0  Walton On The Naze               Essex  ...
# 1           Mill Lane  Walton On The Naze  ...
# 2          Felixstowe             Suffolk  ...
# 3       193 High Road     Trimley St Mary  ...
# 4        Clacton Road       Little Oakley  ...
#
#        LocalAuthorityEmailAddress  \
# 0      fhsadmin@tendringdc.gov.uk
# 1      fhsadmin@tendringdc.gov.uk
# 2  environment@eastsuffolk.gov.uk
# 3  environment@eastsuffolk.gov.uk
# 4      fhsadmin@tendringdc.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 1  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 2  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 3  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 4  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
#
#                                           geocode RightToReply     Distance  \
# 0  {'longitude': 1.270904, 'latitude': 51.848696}               4617.909619
# 1  {'longitude': 1.268522, 'latitude': 51.851497}               4618.100788
# 2   {'longitude': 1.35178, 'latitude': 51.963229}               4619.377042
# 3  {'longitude': 1.313746, 'latitude': 51.984696}               4621.544847
# 4  {'longitude': 1.222682, 'latitude': 51.912376}               4622.042475
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 1            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 2            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 3            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 4            False  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links  \
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
#
#                                       establishments
# 0  {'longitude': None, 'latitude': None, 'RatingV...
# 1  {'longitude': None, 'latitude': None, 'RatingV...
# 2  {'longitude': None, 'latitude': None, 'RatingV...
# 3  {'longitude': None, 'latitude': None, 'RatingV...
# 4  {'longitude': None, 'latitude': None, 'RatingV...
#
# [5 rows x 29 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

match_query = {'$match': {'scores.Hygiene': 0}}
group_query = {'$group': {'_id': '$LocalAuthorityName', 'count': { '$sum': 1 }}}
sort_values = {'$sort': { 'count': -1 }}

pipeline = [match_query, group_query, sort_values]

results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print(len(results))

# Print the first 10 results
pprint(results[0:10])
# Out:
# 55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_df))

# Display the first 5 rows of the DataFrame
result_df.head(5)
# Out:
# Rows in DataFrame:  55
#          _id  count
# 0     Thanet   1130
# 1  Greenwich    882
# 2  Maidstone    713
# 3     Newham    711
# 4      Swale    686
